# %% [markdown]
# Problema 1. Escribe una funcion que calcule raices de ecuaciones de segundo grado. Si el discriminante (b
# 2 − 4ac) es negativo, entonces debe de imprimir
# Error, el discriminante tiene que se positivo debe volver a leer los valores

# %%
print("Este programa calcula la raiz de una ecuacion de segundo grado por la ecuacion general")


a = float(input("Por favor digite el valor de a: "))
b = float(input("Por favor digite el valor de b: "))
c = float(input("Por favor digite el valor de c: "))

x1 = ((-(b) - (((b*2)-(4*a*c))*0.5)) / (2*a))
x2 = ((-(b) + (((b*2)-(4*a*c))*0.5)) / (2*a))

while ((b**2)-(4*a*c)) < 0:
  print("ERROR EL DISCRIMINANTE DEBE SER UN VALOR POSITIVO")
  print("por favor digite valores diferentes")

  a = float(input("Por favor digite el valor de a: "))
  b = float(input("Por favor digite el valor de b: "))
  c = float(input("Por favor digite el valor de c: "))

if ((b**2)-(4*a*c)) > 0:
  x1 = ((-(b) - (((b*2)-(4*a*c))*0.5)) / (2*a))
  x2 = ((-(b) + (((b*2)-(4*a*c))*0.5)) / (2*a))

print("El valor de x1: ", x1)
print("El valor de x2: ", x2)
# Out:
# Este programa calcula la raiz de una ecuacion de segundo grado por la ecuacion general
# Por favor digite el valor de a: 1
# Por favor digite el valor de b: 3
# Por favor digite el valor de c: 2
# El valor de x1:  -1.0
# El valor de x2:  -2.0
