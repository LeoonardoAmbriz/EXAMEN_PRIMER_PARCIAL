# %% [markdown]
# Examen ejercicio 2. Realizar una funcion que acepte el valor de x y calcule el valor de f(x), evalua la funcion en el rango solicitado

# %%
import math
print("Este programa realiza el calculo de la funcion f(x) = e ^ -x ")
x=int(input("Digite el valor de x: "))
e = 2.7182818284

exp= x * (-1)

funcion= e**exp

print("El resultado de la funcion es: ", funcion)

print("Evaluando en el rango de -4 a 10")

miLista=[]
x = -4 -1

while x < 10:
  x+=1
  miLista.append(x)
  a = pow (e, -x)
  if a < 0.0025:
    print("Los valores del rango de la funcion evaluada, son: ", a)
# Out:
# Este programa realiza el calculo de la funcion f(x) = e ^ -x
# Digite el valor de x: 3
# El resultado de la funcion es:  0.0497870683711083
# Evaluando en el rango de -4 a 10
# Los valores del rango de la funcion evaluada, son:  0.002478752176989413
# Los valores del rango de la funcion evaluada, son:  0.0009118819656931688
# Los valores del rango de la funcion evaluada, son:  0.00033546262796080604
# Los valores del rango de la funcion evaluada, son:  0.00012340980411080544
# Los valores del rango de la funcion evaluada, son:  4.539992977234643e-05
